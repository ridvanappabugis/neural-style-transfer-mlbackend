# %%
import tensorflow as tf

from model.NeuralTransferModel import NeuralTransferModel
from util.ImgUtil import load_img, load_img_path, tensor_to_image

# %%
model = NeuralTransferModel()

content_path = tf.keras.utils.get_file('YellowLabradorLook1ing_new.jpg', 'https://uploads8.wikiart.org/00339/images/leonardo-da-vinci/mona-lisa-c-1503-1519.jpg!Blog.jpg')
style_path = tf.keras.utils.get_file('test5.jpg', 'https://uploads3.wikiart.org/00142/images/vincent-van-gogh/the-starry-night.jpg!Blog.jpg')

content_image = load_img_path(content_path)
style_image = load_img_path(style_path)

tensor = model((style_image, content_image, 5, 25))

tensor_to_image(tensor)
# Out:
# .............................................................................................................................
# <PIL.Image.Image image mode=RGB size=344x512 at 0x1ED034E2FA0>

# %%
import os

export_path = os.path.join("C:/Users/Ridvan/Desktop", str(1))


content_path = tf.keras.utils.get_file('content.jpg', 'https://uploads4.wikiart.org/images/nyoman-masriadi/throwing-away-bad-luck-2003.jpg')
style_path = tf.keras.utils.get_file('style.jpg', 'https://uploads3.wikiart.org/00142/images/vincent-van-gogh/the-starry-night.jpg!Blog.jpg')
