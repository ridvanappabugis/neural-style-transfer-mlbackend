# %%
import tensorflow as tf

from model.TestModelFunctional import NeuralTransferModel
from ImgUtil import load_img, imshow, tensor_to_image

model = NeuralTransferModel()

content_path = tf.keras.utils.get_file('YellowLabradorLook1ing_new.jpg', 'https://uploads8.wikiart.org/00339/images/leonardo-da-vinci/mona-lisa-c-1503-1519.jpg!Blog.jpg')
style_path = tf.keras.utils.get_file('test5.jpg', 'https://uploads3.wikiart.org/00142/images/vincent-van-gogh/the-starry-night.jpg!Blog.jpg')

content_image = load_img(content_path)
style_image = load_img(style_path)


result = model((style_image, content_image))


model.summary()
tensor_to_image(result)
# Out:
# ....................................................................................................Model: "NeuralTransferModel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# style_extractor (StyleExtrac multiple                  12944960
# _________________________________________________________________
# content_extractor (ContentEx multiple                  15304768
# _________________________________________________________________
# style_content_loss (StyleCon multiple                  0 (unused)
# =================================================================
# Total params: 28,778,112
# Trainable params: 528,384
# Non-trainable params: 28,249,728
# _________________________________________________________________
# <PIL.Image.Image image mode=RGB size=344x512 at 0x2C1BE69C640>
